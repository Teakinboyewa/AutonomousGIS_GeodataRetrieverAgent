# %%
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached uvicorn-0.38.0-py3-none-any.whl.metadata (6.8 kB)
# ...
# Using cached uvicorn-0.38.0-py3-none-any.whl (68 kB)
# ...
#
#    ---------- ----------------------------- 1/4 [uvicorn]
#    ---------- ----------------------------- 1/4 [uvicorn]
#    -------------------- ------------------- 2/4 [starlette]
#    -------------------- ------------------- 2/4 [starlette]
#    ------------------------------ --------- 3/4 [fastapi]
#    ------------------------------ --------- 3/4 [fastapi]
#    ------------------------------ --------- 3/4 [fastapi]
#    ------------------------------ --------- 3/4 [fastapi]
#    ------------------------------ --------- 3/4 [fastapi]
#    ---------------------------------------- 4/4 [fastapi]
#
# ...
#   WARNING: The script uvicorn.exe is installed in 'C:\Users\akinb\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
# ...

# %%
# !git clone https://github.com/fangwentong/openai-proxy.git
# Out:
# Cloning into 'openai-proxy'...
